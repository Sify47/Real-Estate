# %%
import pandas as pd
import requests
import numpy as np
from bs4 import BeautifulSoup
import time

def scrape_bayut_page(page_url):
    """دالة لجمع البيانات من صفحة واحدة"""
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    
    try:
        response = requests.get(page_url, headers=headers)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
    except Exception as e:
        print(f"خطأ في تحميل الصفحة {page_url}: {e}")
        return []
    
    def text_or_none(selector, parent):
        el = parent.select_one(selector)
        return el.get_text(strip=True) if el else None
    
    # select li cards inside the ul (avoid iterating the ul itself)
    property_cards = soup.select("ul._172b35d1 li")
    properties = []
    
    for card in property_cards:
        try:
            a = card.select_one("a._8969fafd")
            link = f"https://www.bayut.eg{a.get('href')}" if a and a.get('href') else None
            
            price = text_or_none("h4.afdad5da._71366de7 span.eff033a6", card) or text_or_none("span.eff033a6", card)
            title = text_or_none("h2._34c51035", card)
            
            spans = card.select("span._3002c6fb")
            type_ = spans[0].get_text(strip=True) if len(spans) > 0 else None
            bedrooms = spans[1].get_text(strip=True) if len(spans) > 1 else None
            bathrooms = spans[2].get_text(strip=True) if len(spans) > 2 else None
            
            location = text_or_none("h3._51c6b1ca", card)
            d = text_or_none("span.fd7ade6e", card)
            
            area_raw = text_or_none("h4._60820635._07b5f28e", card) or text_or_none("h4", card)
            area = area_raw[:-6] if area_raw and len(area_raw) > 6 else area_raw
            
            properties.append({
                'PropertyType': type_,
                'Link': link,
                'Title': title,
                'Price': price,
                'Location': location,
                'Area': area,
                'Bedrooms': bedrooms,
                'Bathrooms': bathrooms,
                'Down_Payment': d,
            })
        except Exception as e:
            print(f"خطأ في معالجة كارد: {e}")
            continue
    
    return properties

def scrape_all_pages(base_url, max_pages=20):
    """دالة لجمع البيانات من جميع الصفحات"""
    all_properties = []
    
    # الصفحة الأولى
    print(f"جاري جمع البيانات من الصفحة 1...")
    page1_properties = scrape_bayut_page(base_url)
    all_properties.extend(page1_properties)
    print(f"تم جمع {len(page1_properties)} عقار من الصفحة 1")
    
    # الصفحات التالية
    for page_num in range(2, max_pages + 1):
        page_url = f"{base_url.rstrip('/')}/page-{page_num}/"
        print(f"جاري جمع البيانات من الصفحة {page_num}...")
        
        properties = scrape_bayut_page(page_url)
        
        # إذا لم نجد عقارات في هذه الصفحة، توقف
        if not properties:
            print(f"لم يتم العثور على عقارات في الصفحة {page_num}. التوقف...")
            break
        
        all_properties.extend(properties)
        print(f"تم جمع {len(properties)} عقار من الصفحة {page_num}")
        
        # تأخير بسيط لتجنب حظر IP
        time.sleep(1)
    
    return all_properties

# استخدام الدالة
base_url = "https://www.bayut.eg/en/alexandria/properties-for-sale/"
all_properties = scrape_all_pages(base_url, max_pages=20)  # يمكنك زيادة عدد الصفحات

df = pd.DataFrame(all_properties)
def clean_data(df_clean):
    # Split text using string ',' in column: 'Location'
    loc_0 = df_clean.columns.get_loc('Location')
    df_clean_split = df_clean['Location'].str.split(pat=',', expand=True).add_prefix('Location_')
    df_clean = pd.concat([df_clean.iloc[:, :loc_0], df_clean_split, df_clean.iloc[:, loc_0:]], axis=1)
    df_clean = df_clean.drop(columns=['Location'])
    # Drop column: 'Location_2'
    df_clean = df_clean.drop(columns=['Location_2'])
    # Rename column 'Location_1' to 'State'
    df_clean = df_clean.rename(columns={'Location_1': 'State'})
    # Rename column 'Location_0' to 'Location'
    df_clean = df_clean.rename(columns={'Location_0': 'Location'})
    # Replace all instances of "Saba Pasha" with "Saba Basha" in column: 'State'
    df['State'] = df['State'].str.replace("Saba Pasha", "Saba Basha", case=False, regex=False)
    # Replace all instances of "Borg al-Arab" with "Borg El Arab" in column: 'State'
    df['State'] = df['State'].str.replace("Borg al-Arab", "Borg El Arab", case=False, regex=False)
    # Replace all instances of "Smoha" with "Smouha" in column: 'Location'
    df['Location'] = df['Location'].str.replace("Smoha", "Smouha", case=False, regex=False)
    return df_clean

df_clean_1 = clean_data(df.copy())
df1 = df_clean_1.copy()
df1['Down_Payment']= df1['Down_Payment'].fillna(0)
df1.isnull().sum()
df1.dropna(inplace=True)
df1.reset_index(drop=True, inplace=True)
df1

df_clean = df1.copy()
df_clean['State'] = df_clean['State'].str.strip()
mask = df_clean['State'].str.contains('Alexandria', case=False, na=False)
df_clean.loc[mask, 'State'] = df_clean.loc[mask, 'Location']
df_clean['State'] = df_clean['State'].fillna(df_clean['Location'])
df_clean['State'] = df_clean['State'].str.strip()
df_clean['Location'] = df_clean['Location'].str.strip()
df_clean['Payment_Method'] = ""
df_clean.loc[df_clean['Down_Payment'].astype(str).str.strip() != "0", 'Payment_Method'] = "Installments"
df_clean.loc[df_clean['Payment_Method'] == "", 'Payment_Method'] = "Cash"

df_final = pd.read_csv("E:\PY\Real Estate\Final.csv")
df_combined = pd.concat([df_final, df_clean], ignore_index=True)
df_combined.to_csv("E:\PY\Real Estate\Final.csv", index=False)
print("Datasets combined and saved successfully.")

df11 = pd.read_csv("E:\PY\Real Estate\Final.csv")
df11.drop_duplicates(inplace=True)
df11.to_csv("E:\PY\Real Estate\Final.csv", index=False)
# Out:
# جاري جمع البيانات من الصفحة 1...
# تم جمع 26 عقار من الصفحة 1
# جاري جمع البيانات من الصفحة 2...
# تم جمع 26 عقار من الصفحة 2
# تنظيف State مكتمل!
# أمثلة بعد التنظيف:
#          Location  State
# 0  Orouba Skyline  Smoha
# 1         The One  Smoha
# 2       Alex West  Agami
# 3       Alex West  Agami
# 4  Orouba Skyline  Smoha
#    PropertyType                                               Link  \
# 0     Apartment  https://www.bayut.eg/en/property/details-50299...
# 1     Apartment  https://www.bayut.eg/en/property/details-50299...
# 2     Apartment  https://www.bayut.eg/en/property/details-50299...
# 3     Townhouse  https://www.bayut.eg/en/property/details-50289...
# 4     Apartment  https://www.bayut.eg/en/property/details-50274...
# 5     Apartment  https://www.bayut.eg/en/property/details-50288...
# 6         Villa  https://www.bayut.eg/en/property/details-50299...
# 7     Apartment  https://www.bayut.eg/en/property/details-50299...
# 8     Apartment  https://www.bayut.eg/en/property/details-50299...
# 9     Apartment  https://www.bayut.eg/en/property/details-50299...
# 10    Apartment  https://www.bayut.eg/en/property/details-50299...
# 11    Apartment  https://www.bayut.eg/en/property/details-50284...
# 12    Apartment  https://www.bayut.eg/en/property/details-50284...
# 13    Apartment  https://www.bayut.eg/en/property/details-50270...
# 14    Apartment  https://www.bayut.eg/en/property/details-50286...
# 15    Apartment  https://www.bayut.eg/en/property/details-50299...
# 16    Apartment  https://www.bayut.eg/en/property/details-50299...
# 17    Apartment  https://www.bayut.eg/en/property/details-50299...
# 18    Apartment  https://www.bayut.eg/en/property/details-50286...
# 19    Apartment  https://www.bayut.eg/en/property/details-50298...
# 20    Apartment  https://www.bayut.eg/en/property/details-50298...
# 21    Apartment  https://www.bayut.eg/en/property/details-50298...
# 22    Apartment  https://www.bayut.eg/en/property/details-50284...
# 23    Apartment  https://www.bayut.eg/en/property/details-50281...
# 24    Apartment  https://www.bayut.eg/en/property/details-50298...
# 25    Apartment  https://www.bayut.eg/en/property/details-50298...
# 26    Apartment  https://www.bayut.eg/en/property/details-50298...
# 27    Apartment  https://www.bayut.eg/en/property/details-50298...
# 28    Apartment  https://www.bayut.eg/en/property/details-50298...
# 29        Villa  https://www.bayut.eg/en/property/details-50298...
# 30    Apartment  https://www.bayut.eg/en/property/details-50297...
# 31    Apartment  https://www.bayut.eg/en/property/details-50297...
# 32    Apartment  https://www.bayut.eg/en/property/details-50297...
# 33    Apartment  https://www.bayut.eg/en/property/details-50297...
# 34    Apartment  https://www.bayut.eg/en/property/details-50297...
# 35    Apartment  https://www.bayut.eg/en/property/details-50297...
# 36    Apartment  https://www.bayut.eg/en/property/details-50299...
# 37    Apartment  https://www.bayut.eg/en/property/details-50297...
# 38    Apartment  https://www.bayut.eg/en/property/details-50297...
# 39    Apartment  https://www.bayut.eg/en/property/details-50297...
# 40    Apartment  https://www.bayut.eg/en/property/details-50297...
# 41        Villa  https://www.bayut.eg/en/property/details-50296...
# 42    Apartment  https://www.bayut.eg/en/property/details-50296...
# 43        Villa  https://www.bayut.eg/en/property/details-50297...
# 44    Apartment  https://www.bayut.eg/en/property/details-50296...
# 45    Apartment  https://www.bayut.eg/en/property/details-50296...
# 46    Apartment  https://www.bayut.eg/en/property/details-50280...
# 47        Villa  https://www.bayut.eg/en/property/details-50296...
#
#                                                 Title       Price  \
# 0   Apartment for sale, 149 m in Skyline delivery ...   6,055,000
# 1   Apartment for sale 179 m The One compound Smou...  11,258,026
# 2   Apartment for sale 153 m with a view directly ...   5,500,000
# 3   Receive your townhouse with an open lake view ...  13,000,000
# 4   Receive your hotel-finished apartment immediat...  10,000,000
# 5   Own your apartment with a direct club view in ...   8,600,000
# 6   Villa for sale 1,030 sqm in Alex West immediat...  35,000,000
# 7   Apartment for sale 175 sqm Sawary with install...   7,454,240
# 8   Apartment 134 m for sale in Smouha Albert elaw...   8,440,000
# 9   Apartment for sale 180 m in Smouha The One com...  11,529,000
# 10  apartment for sale 198 m in Valore smouha Comp...   9,108,000
# 11  Apartment for sale, 400 sq m, Smouha - directl...  12,000,000
# 12  Apartment for sale, 210 sq m, Smouha - Taqsim ...   7,500,000
# 13  Apartment for sale, 170 m², Kafr Abdo - Amir E...   5,200,000
# 14  Apartment for sale in Alex West Compound, Unit...   8,549,000
# 15  Receive your apartment immediately with 3-year...   7,454,240
# 16  Apartment for sale in Palm Hills Alexandria 13...  10,580,000
# 17  Apartment for sale 184 sqm Alex West immediate...   6,500,000
# 18  Apartment for sale 190 m² Gleem (Qasr Al Margh...   8,700,000
# 19  Own the largest apartment in Sawary with a pre...   8,200,000
# 20  Own 177 m apartment at the lowest price on the...   7,873,000
# 21  Own a 208 m apartment in Smouha Barons Compoun...  11,000,000
# 22  Your apartment in Sharawy with one-year facili...   6,600,000
# 23  Apartment for sale, 105 sq m, Loran (El Eqbal ...   3,500,000
# 24  Own an apartment with immediate delivery in Al...   6,500,000
# 25  Receive your apartment immediately in Alex Wes...   6,300,000
# 26       Own an apartment with an open view in Sawary   9,030,000
# 27  Apartment for sale 160 sqm with open view on t...   3,700,000
# 28  Luxurious apartment for sale 300 m at Loran Na...  11,000,000
# 29  Own a twin house villa in Smouha with ultra lu...  21,700,000
# 30          Apartment for sale, 202 sq m, San Stefano   9,000,000
# 31  Own an apartment with an open view overlooking...  14,500,000
# 32  Receive your apartment within 4 months with 3-...   9,462,000
# 33  Own a 3-bedroom apartment with a distinctive l...   9,555,000
# 34       Own an apartment with an open view in Sawary   8,758,000
# 35  Own an apartment at the lowest price per squar...   8,736,000
# 36  205 sqm apartment for sale in Sawary immediate...   8,200,000
# 37  View your unit live at Alex West with 3-year p...   8,250,000
# 38  Own your apartment in Alex West with installme...   8,250,000
# 39  Own your unit in Sawary with a view of Plaza a...   9,620,000
# 40  Own your apartment in the most prime towers of...  15,859,200
# 41  Standalone villa for sale, 309 sq m + 205 sq m...  24,750,000
# 42  Receive your duplex within 4 months with 4-yea...  12,201,000
# 43              Your villa at the old price in Sawary  11,500,000
# 44  Own an apartment with an open view overlooking...   5,175,000
# 45  Apartment for sale, 170 m² Smouha (Al Sayadah ...   5,500,000
# 46  Own your apartment with the nearest delivery a...   5,500,000
# 47  Receive immediately a twin house villa in Alex...  15,500,000
#
#                  Location        State    Area Bedrooms Bathrooms  \
# 0          Orouba Skyline        Smoha    149         3         3
# 1                 The One        Smoha    179         3         2
# 2               Alex West        Agami    153         3         2
# 3               Alex West        Agami    180         3         2
# 4          Orouba Skyline        Smoha    206         3         3
# 5                  Murooj        Smoha    207         3         3
# 6               Alex West        Agami  1,030         6         6
# 7                  Sawari  Moharam Bik    175         3         3
# 8                 The One        Smoha    134         3         2
# 9                 The One        Smoha    180         4         2
# 10                 Valore        Smoha    198         3         3
# 11                  Smoha        Smoha    400         4         4
# 12                  Smoha        Smoha    210         4         2
# 13              Kafr Abdo    Kafr Abdo    170         3         2
# 14              Alex West        Agami    184         3         3
# 15                 Sawari  Moharam Bik    175         3         3
# 16  Palm Hills Alexandria       Amreya    138         2         3
# 17              Alex West        Agami    184         3         3
# 18                   Glim         Glim    190         3         2
# 19                 Sawari  Moharam Bik    205         3         3
# 20                 Sawari  Moharam Bik    177         3         3
# 21                  Smoha        Smoha    208         3         3
# 22                Laurent      Laurent    175         3         2
# 23                Laurent      Laurent    105         2         1
# 24              Alex West        Agami    184         3         3
# 25              Alex West        Agami    155         3         2
# 26                 Sawari  Moharam Bik    210         4         3
# 27                  Miami        Miami    160         3         2
# 28                  Smoha        Smoha    300         4         3
# 29                 Murooj        Smoha    279         6         5
# 30            San Stefano  San Stefano    202         3         3
# 31  Palm Hills Alexandria       Amreya    168         3         3
# 32                 Sawari  Moharam Bik    166         3         2
# 33                 Murooj        Smoha    195         3         3
# 34                 Sawari  Moharam Bik    151         3         2
# 35                 Sawari  Moharam Bik    168         3         3
# 36                 Sawari  Moharam Bik    205         3         3
# 37              Alex West        Agami    217         4         3
# 38              Alex West        Agami    217         4         3
# 39                 Sawari  Moharam Bik    148         3         2
# 40                 Sawari  Moharam Bik    177         3         3
# 41                  Smoha        Smoha    514         5         4
# 42                 Sawari  Moharam Bik    249         4         3
# 43                 Sawari  Moharam Bik    244         4         4
# 44                 Murooj        Smoha    138         3         2
# 45                  Smoha        Smoha    170         3         2
# 46              Alex West        Agami    184         3         3
# 47              Alex West        Agami    328         5         3
#
#      Down_Payment Payment_Method
# 0   EGP 4,800,000   Installments
# 1   EGP 3,089,090   Installments
# 2               0           Cash
# 3               0           Cash
# 4               0           Cash
# 5               0           Cash
# 6               0           Cash
# 7   EGP 5,250,000   Installments
# 8   EGP 2,100,000   Installments
# 9   EGP 2,445,581   Installments
# 10  EGP 4,554,000   Installments
# 11              0           Cash
# 12              0           Cash
# 13              0           Cash
# 14    EGP 425,000   Installments
# 15  EGP 5,250,000   Installments
# 16  EGP 1,700,000   Installments
# 17              0           Cash
# 18              0           Cash
# 19              0           Cash
# 20              0           Cash
# 21              0           Cash
# 22              0           Cash
# 23              0           Cash
# 24              0           Cash
# 25              0           Cash
# 26  EGP 3,160,500   Installments
# 27              0           Cash
# 28              0           Cash
# 29              0           Cash
# 30              0           Cash
# 31  EGP 1,675,000   Installments
# 32  EGP 3,300,000   Installments
# 33    EGP 955,500   Installments
# 34  EGP 2,189,500   Installments
# 35  EGP 1,092,000   Installments
# 36              0           Cash
# 37  EGP 3,900,000   Installments
# 38  EGP 3,900,000   Installments
# 39  EGP 1,924,000   Installments
# 40  EGP 1,585,920   Installments
# 41  EGP 3,093,750   Installments
# 42  EGP 4,270,350   Installments
# 43              0           Cash
# 44              0           Cash
# 45              0           Cash
# 46              0           Cash
# 47  EGP 7,750,000   Installments
